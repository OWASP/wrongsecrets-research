# %% [markdown]
# # WrongSecrets Git Notes Research

# %% [markdown]
# The purpose of this research is to evaluate usage of git notes in prominent GitHub repositories. We want to test whether git notes are still used. We expect they aren't, so in research fashion, in this notebook we'll see if the null hypothesis (git notes are used) can be rejected.
#
# For those repositories that use git notes, we'll evaluate to what extent, and how.

# %% [markdown]
# ## Prerequisites
#
# First, we need to install and load some libraries, and load the dataset that we collected earlier (collected using the code posted in https://github.com/RemakingEden/git-notes-research)

# %%
import duckdb
import pandas as pd
import matplotlib.pyplot as plt

# %%
# create a connection to a file called 'file.db'
con = duckdb.connect('databases/1000-repos.db')

# %% [markdown]
# ## Exploratory data analysis
# Let's get the tables and print some example entries along with their schema.

# %%
# Get the available tables
con.execute("SELECT * FROM sqlite_master WHERE type='table';").fetchdf()
# Out:
#     type   name tbl_name  rootpage  \
# 0  table  repos    repos         0
# 1  table  notes    notes         0
#
#                                                  sql
# 0  CREATE TABLE repos(id VARCHAR, "name" VARCHAR ...
# 1  CREATE TABLE notes(id VARCHAR, repo_id VARCHAR...

# %%
# Get the available columns from the repos table
con.execute("SELECT * FROM repos LIMIT 1;").fetchdf()
# Out:
#                            id          name       license   stars  has_notes  \
# 0  01HDSEZ50PZNBDQAHHCTW0N423  freeCodeCamp  bsd-3-clause  376458      False
#
#    notes_count  total_contributors     repo_created_at     repo_updated_at  \
# 0            0                 395 2014-12-24 17:49:19 2023-10-27 20:09:41
#
#                created_at              updated_at
# 0 2023-10-27 20:59:45.860 2023-10-27 20:59:45.860

# %%
con.execute("SELECT * FROM notes LIMIT 1;").fetchdf()
# Out:
#                            id                     repo_id  \
# 0  01HDSGGWKD74K4KZ7VSGHA138B  01HDSGERYG0ABHDA7TMMAFGJ7Y
#
#                                              content         note_created_at  \
# 0  PR-URL: #11006\nReviewed-By: Michael Dawson <m... 2017-02-09 20:19:14.123
#
#                                    note_ref  \
# 0  901e926d43a875af0bf2164c62770f7a835edf19
#
#                               author              created_at  \
# 0  Sam Roberts <vieuxtech@gmail.com> 2023-10-27 21:26:55.341
#
#                updated_at
# 0 2023-10-27 21:26:55.341

# %% [markdown]
# Let's visualize the number of repositores with notes vs without notes.

# %%
df = con.execute("SELECT * FROM repos;").fetchdf()
df.head()
# Out:
#                            id                         name       license  \
# 0  01HDSEZ50PZNBDQAHHCTW0N423                 freeCodeCamp  bsd-3-clause
# 1  01HDSF090VSM9Y19N5753STDGG       free-programming-books     cc-by-4.0
# 2  01HDSF0G2G1DD9030TQF9FXVZN                      awesome       cc0-1.0
# 3  01HDSF0KX5733J6DH0Y7FVCNR1  coding-interview-university  cc-by-sa-4.0
# 4  01HDSF0V8Q6EBAKY5B0YEHNEG3                      996.ICU         other
#
#     stars has_notes  notes_count  total_contributors     repo_created_at  \
# 0  376458     False          0.0               395.0 2014-12-24 17:49:19
# 1  301963     False          0.0               430.0 2013-10-11 06:50:37
# 2  274997     False          0.0               435.0 2014-07-11 13:42:37
# 3  270143     False          0.0               289.0 2016-06-06 02:34:12
# 4  268074     False          0.0               402.0 2019-03-26 07:31:14
#
#       repo_updated_at              created_at              updated_at
# 0 2023-10-27 20:09:41 2023-10-27 20:59:45.860 2023-10-27 20:59:45.860
# 1 2023-10-27 20:55:34 2023-10-27 21:00:22.428 2023-10-27 21:00:22.428
# 2 2023-10-27 20:39:52 2023-10-27 21:00:29.648 2023-10-27 21:00:29.648
# 3 2023-10-27 20:07:07 2023-10-27 21:00:33.573 2023-10-27 21:00:33.573
# 4 2023-10-27 19:25:15 2023-10-27 21:00:41.111 2023-10-27 21:00:41.111

# %%
df['has_notes'].value_counts().plot(kind='bar', title='Number of Repos with Notes', xlabel='Has Notes', ylabel='Number of Repos')
# Out:
# <Axes: title={'center': 'Number of Repos with Notes'}, xlabel='Has Notes', ylabel='Number of Repos'>

# %% [markdown]
# When were those notes added, and how many authors did this? Let's plot a timeline.

# %%
df_notes = con.execute("SELECT notes.*, repos.name FROM notes LEFT JOIN repos ON notes.repo_id = repos.id;").fetchdf()
df_notes.head()
# Out:
#                            id                     repo_id  \
# 0  01HDSGGWKD74K4KZ7VSGHA138B  01HDSGERYG0ABHDA7TMMAFGJ7Y
# 1  01HDSHHYBP3WGR3PWRTPV4QMDM  01HDSHHCRZBMNRSZ7ASE5CSY48
# 2  01HDSJ59C38V895064YHZXC888  01HDSJ53052D3S6XWTRK33KVB9
# 3  01HDSJPD9J4GJ653ZJ8WWNS75P  01HDSJPCRDF9VRPF99VVQ31S5S
# 4  01HDSMVJSZ8CBXXTT2GND4CT91  01HDSMTB8MG5JPAN1K5VHGGRPH
#
#                                              content         note_created_at  \
# 0  PR-URL: #11006\nReviewed-By: Michael Dawson <m... 2017-02-09 20:19:14.123
# 1                                     Fixes gh-563\n 2014-03-24 18:44:52.123
# 2  This also adds extracting storyboards from DAS... 2021-06-13 15:06:40.123
# 3                   Issue: SPR-9007 (not SPR-9014)\n 2012-02-13 14:01:06.123
# 4                                     another note\n 2019-07-16 18:23:13.123
#
#                                    note_ref  \
# 0  901e926d43a875af0bf2164c62770f7a835edf19
# 1  d42bedf295cfad3a9edbb3e0a032c14629737460
# 2  cdb19aa4c254a1e4dea942f51d22790b7c99021c
# 3  0a5392e37d268d4df9526216531a6655e52b9f38
# 4  e46ff190351a96adaf3a8477b9ee59aefa640495
#
#                                               author              created_at  \
# 0                  Sam Roberts <vieuxtech@gmail.com> 2023-10-27 21:26:55.341
# 1                 Phillip Webb <pwebb@gopivotal.com> 2023-10-27 21:44:58.487
# 2                      felix <felix.von.s@posteo.de> 2023-10-27 21:55:32.356
# 3                    Chris Beams <cbeams@vmware.com> 2023-10-27 22:04:53.427
# 4  Ben Kucera <14625260+Bkucera@users.noreply.git... 2023-10-27 22:42:40.064
#
#                updated_at              name
# 0 2023-10-27 21:26:55.341              node
# 1 2023-10-27 21:44:58.487       spring-boot
# 2 2023-10-27 21:55:32.356            yt-dlp
# 3 2023-10-27 22:04:53.427  spring-framework
# 4 2023-10-27 22:42:40.064           cypress

# %%
# Plot the amount of notes per repo
df_notes['name'].value_counts().plot(kind='bar', title='Amount of notes per repo')
# Out:
# <Axes: title={'center': 'Amount of notes per repo'}, xlabel='name'>

# %%
# Plot the amount of notes per author
df_notes['author'].value_counts().plot(kind='bar', title='Amount of notes per author')
# Out:
# <Axes: title={'center': 'Amount of notes per author'}, xlabel='author'>

# %% [markdown]
# What kind of licenses do repos with notes have?

# %%
df[df['has_notes'].fillna(False)]['license'].value_counts().plot(kind='bar', title='License types of repos with notes')
# Out:
# <Axes: title={'center': 'License types of repos with notes'}, xlabel='license'>

# %%
# amount of stars for repos with notes
df[df['has_notes'].fillna(False)]['stars'].plot(kind='bar', title='Amount of stars for repos with notes')
# Out:
# <Axes: title={'center': 'Amount of stars for repos with notes'}>

# %%
# amount of contributors per repo with notes
df[df['has_notes'].fillna(False)]['total_contributors'].value_counts().plot(kind='bar', title='Amount of contributors per repo with notes')
# Out:
# <Axes: title={'center': 'Amount of contributors per repo with notes'}, xlabel='total_contributors'>
